# %%
import pandas as pd
from datetime import datetime

# %%
def initialize_budget():
    while True:
        try:
            budget = float(input("Enter your total budget: "))
            if budget > 0:
                return budget
            print("Budget must be positive!")
        except:
            print("Please enter a valid number.")

# %%
def expenses(budget, total_budget, category, amount):
    category = category.lower()
    if amount <= 0:
        print("Amount must be positive!")
        return budget
    if category not in categories:
        print(f"Invalid category! Choose from {categories}")
        return budget
    if amount > budget:
        print("Transaction failed: Not enough budget!")
        return budget
    
    budget -= amount
    transactions.append({
        "date": datetime.now().strftime("%Y-%m-%d"),
        "category": category,
        "amount": amount,
        "total_budget": total_budget,
        "remaining_balance": budget
    })
    print(f"Expense added: {amount} in {category}. Remaining balance: {budget}")
    return budget

# %%
def get_transactions(total_budget, remaining_balance):
    if not transactions:
        print("No transactions.")
        return
    
    df = pd.DataFrame(transactions)
    category_totals = df.groupby('category')['amount'].sum().reset_index()
    category_totals.columns = ['category', 'total_spent']
    
    total_budget_df = pd.DataFrame({"Total Budget": [total_budget]})
    transactions_df = pd.DataFrame(transactions)
    category_totals = transactions_df.groupby('category')['amount'].sum().reset_index()
    category_totals.columns = ['category', 'total_spent']
    remaining_balance_df = pd.DataFrame({"Remaining Balance": [remaining_balance]})
    
    with open("transaction.csv", "w") as f:
        f.write(f"Total Budget,{total_budget}\n\n")
        f.write("Transactions\n")
        df.to_csv(f, index=False, header=True)
        f.write("\nCategory Totals\n")
        if not category_totals.empty:
            category_totals.to_csv(f, index=False, header=True)
        else:
            f.write("No transactions.\n")
        f.write(f"\nRemaining Balance,{remaining_balance}\n")
    
    print("Saved to transaction.csv")

# %%
def main():
    total_budget = initialize_budget()
    budget = total_budget
    
    while True:
        print("\n1. Add new category")
        print("2. Select existing category")
        print("3. Save and exit")
        choice = input("Enter choice (1, 2, or 3): ")
        
        if choice == "1":
            category = input("Enter new category: ").strip().lower()
            if not category:
                print("Category cannot be empty!")
            elif category in categories:
                print("Category already exists!")
            else:
                categories.add(category)
                print(f"Added category: {category}")
                while True:
                    try:
                        amount = float(input("Enter amount for this category: ").strip())
                        break
                    except:
                        print("Please enter a valid amount (integer or float).")
                budget = expenses(budget, total_budget, category, amount)
            
        elif choice == "2":
            if not categories:
                print("No categories available! Please add a category first.")
                continue
            category = input(f"Enter category {categories}: ").lower()
            while True:
                try:
                    amount = float(input("Enter amount: ").strip())
                    break
                except:
                    print("Please enter a valid amount (integer or float).")
            budget = expenses(budget, total_budget, category, amount)
            
        elif choice == "3":
            get_transactions(total_budget, budget)
            print(f"Total budget: {total_budget}")
            print(f"Final balance: {budget}")
            break
            
        else:
            print("Please enter 1, 2, or 3.")

categories = set()
transactions = []
main()
# Out:
# Enter your total budget: 12000
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 1
# Enter new category: food
# Added category: food
# Enter amount for this category: 1300
# Expense added: 1300.0 in food. Remaining balance: 10700.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 2
# Enter category {'food'}: food
# Enter amount: 700
# Expense added: 700.0 in food. Remaining balance: 10000.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 1
# Enter new category: travel
# Added category: travel
# Enter amount for this category: 750
# Expense added: 750.0 in travel. Remaining balance: 9250.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 1
# Enter new category: bills
# Added category: bills
# Enter amount for this category: 1650
# Expense added: 1650.0 in bills. Remaining balance: 7600.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 2
# Enter category {'bills', 'travel', 'food'}: travel
# Enter amount: 399
# Expense added: 399.0 in travel. Remaining balance: 7201.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): food
# Please enter 1, 2, or 3.
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 1400
# Please enter 1, 2, or 3.
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 2
# Enter category {'bills', 'travel', 'food'}: bills
# Enter amount: 755
# Expense added: 755.0 in bills. Remaining balance: 6446.0
#
# 1. Add new category
# 2. Select existing category
# 3. Save and exit
# Enter choice (1, 2, or 3): 3
# Saved to transaction.csv
# Total budget: 12000.0
# Final balance: 6446.0
